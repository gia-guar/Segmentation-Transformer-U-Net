# %% [markdown]
# # BRAIN TUMOR SEGMENTATION
# Data available at https://www.kaggle.com/datasets/mateuszbuda/lgg-mri-segmentation
#
# ## 0. libraries

# %%
import tensorflow_io as tfio
import numpy as np 
import pandas as pd 
import PIL
import glob
import os
import matplotlib.pyplot as plt
import random
from tqdm import tqdm

from sklearn.model_selection import train_test_split

# %matplotlib inline
plt.style.use('dark_background')

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
import tensorflow as tf

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## 1. Example-Label pairing
#
# Identify examples and labels

# %%
# get the images file paths
filenames = []
for path, currentDirectory, files in os.walk("lgg-mri-segmentation"):
    for file in files:
        if file.endswith('.tif'):
            filenames.append(path + '/' + file)
filenames = sorted(filenames)

original = []
mask = []
for image in filenames:
    if image.endswith('mask.tif'):
        mask.append(image)
    else:
        original.append(image)

mask = sorted(mask, key = len)
original = sorted(original, key = len)
data = pd.DataFrame({'original': original, 'mask':mask})
data.head(10)

nSamples = len(original)
print('dataset features a total of: ',nSamples,' labelled examples')
# Out:
# dataset features a total of:  3929  labelled examples

# %% [markdown]
# Load and show a train example

# %%
idx = np.random.randint(0,nSamples-1)
img = PIL.Image.open(data['original'][idx])
lbl = PIL.Image.open(data['mask'][idx])

fig, axs = plt.subplots(1,3)
axs[0].imshow(img), axs[0].set_title('original')
axs[1].imshow(lbl), axs[1].set_title('label')
axs[2].imshow(img), axs[2].set_title('manual segmentation')
axs[2].imshow(lbl, alpha=0.5 * (np.array(lbl) > 0))
fig.suptitle('Data')
fig.tight_layout()
plt.show()

# %%
img_size = np.array(img).shape[:2]
img_shape= np.array(img).shape

print('each example has dimension: ', img_size)
print('each array has shape:    ', img_shape)
# Out:
# each example has dimension:  (256, 256)
# each array has shape:     (256, 256, 3)

# %% [markdown]
# ## 2. Dataset creation

# %% [markdown]
# train - val splitting

# %%
x_train, x_test = train_test_split(data, test_size = 0.2, shuffle=True)

# %% [markdown]
# Data loading and preprocessing using Image Generators

# %%
BATCHSIZE = 16
def preprocess(img, mask):
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    return (img, mask)

def create_gen(x):
    gen = ImageDataGenerator(
        rescale=1./255
    )

    img_gen = gen.flow_from_dataframe(pd.DataFrame(x), 
                                      x_col='original',
                                      class_mode=None, 
                                      target_size=img_size,
                                      batch_size=BATCHSIZE,
                                      shuffle=False
                                     )
    
    mask_gen = gen.flow_from_dataframe(pd.DataFrame(x), 
                                      x_col='mask',
                                      class_mode=None, 
                                      target_size=img_size,
                                      batch_size=BATCHSIZE,
                                      shuffle=False
                                     )
    generator = zip(img_gen, mask_gen)
    
    for (img, mask) in generator:
        img, mask = preprocess(img, mask)
        yield (img, mask)

train = create_gen(x_train)
val = create_gen(x_test)

# %% [markdown]
# ## 3. Model creation
# 4 layers U-Net

# %%
img_input = layers.Input(img_shape)

# Block 1
x = layers.Conv2D(32, (3, 3), padding='same', name='block1_conv1')(img_input)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(32, (3, 3), padding='same', name='block1_conv2')(x)
x = layers.BatchNormalization()(x)
block_1_out = layers.Activation('relu')(x)
x = layers.MaxPooling2D()(block_1_out)

# Block 2
x = layers.Conv2D(64, (3, 3), padding='same', name='block2_conv1')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(64, (3, 3), padding='same', name='block2_conv2')(x)
x = layers.BatchNormalization()(x)
block_2_out = layers.Activation('relu')(x)
x = layers.MaxPooling2D()(block_2_out)

# Block 3
x = layers.Conv2D(128, (3, 3), padding='same', name='block3_conv1')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(128, (3, 3), padding='same', name='block3_conv2')(x)
x = layers.BatchNormalization()(x)
block_3_out = layers.Activation('relu')(x)
x = layers.MaxPooling2D()(block_3_out)

# Block 4
x = layers.Conv2D(256, (3, 3), padding='same', name='block4_conv1')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(256, (3, 3), padding='same', name='block4_conv2')(x)
x = layers.BatchNormalization()(x)
block_4_out = layers.Activation('relu')(x)
x = layers.MaxPooling2D()(block_4_out)

# Block 5
x = layers.Conv2D(512, (3, 3), padding='same', name='block5_conv1')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(512, (3, 3), padding='same', name='block5_conv2')(x)
x = layers.BatchNormalization()(x)
block_5_out = layers.Activation('relu')(x)

# UP 1
x = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same', name = 'Conv2DTranspose_UP1')(block_5_out)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.concatenate([x, block_4_out])
x = layers.Conv2D(256, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(256, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

# UP 2
x = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same', name = 'Conv2DTranspose_UP2')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.concatenate([x, block_3_out])
x = layers.Conv2D(128, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(128, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

# UP 3
x = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same', name = 'Conv2DTranspose_UP3')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.concatenate([x, block_2_out])
x = layers.Conv2D(64, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(64, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

# UP 4
x = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same', name = 'Conv2DTranspose_UP4')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.concatenate([x, block_1_out])
x = layers.Conv2D(32, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(32, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

# OUT
x = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

model = Model(img_input, x)
model.compile(optimizer=Adam(lr=0.005), loss='binary_crossentropy')
# Out:
# e:\Data\documenti\PROGRAMMAZIONE\Segmentation\autoencoders\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 256, 256, 32  896         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_66 (BatchN  (None, 256, 256, 32  128        ['block1_conv1[0][0]']
#  ormalization)                  )
#
#  activation_66 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_66[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 256, 256, 32  9248        ['activation_66[0][0]']
#                                 )
#
#  batch_normalization_67 (BatchN  (None, 256, 256, 32  128        ['block1_conv2[0][0]']
#  ormalization)                  )
#
#  activation_67 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_67[0][0]']
#                                 )
#
#  max_pooling2d_16 (MaxPooling2D  (None, 128, 128, 32  0          ['activation_67[0][0]']
#  )                              )
#
#  block2_conv1 (Conv2D)          (None, 128, 128, 64  18496       ['max_pooling2d_16[0][0]']
#                                 )
#
#  batch_normalization_68 (BatchN  (None, 128, 128, 64  256        ['block2_conv1[0][0]']
#  ormalization)                  )
#
#  activation_68 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_68[0][0]']
#                                 )
#
#  block2_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['activation_68[0][0]']
#                                 )
#
#  batch_normalization_69 (BatchN  (None, 128, 128, 64  256        ['block2_conv2[0][0]']
#  ormalization)                  )
#
#  activation_69 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_69[0][0]']
#                                 )
#
#  max_pooling2d_17 (MaxPooling2D  (None, 64, 64, 64)  0           ['activation_69[0][0]']
#  )
#
#  block3_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 64, 64, 128)  512        ['block3_conv1[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_70[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['activation_70[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 64, 64, 128)  512        ['block3_conv2[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_71[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 32, 32, 128)  0          ['activation_71[0][0]']
#  )
#
#  block4_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['max_pooling2d_18[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 32, 32, 256)  1024       ['block4_conv1[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_72[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['activation_72[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 32, 32, 256)  1024       ['block4_conv2[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_73[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 16, 16, 256)  0          ['activation_73[0][0]']
#  )
#
#  block5_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['max_pooling2d_19[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 16, 16, 512)  2048       ['block5_conv1[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_74[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['activation_74[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 16, 16, 512)  2048       ['block5_conv2[0][0]']
#  ormalization)
#
#  activation_75 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_75[0][0]']
#
#  Conv2DTranspose_UP1 (Conv2DTra  (None, 32, 32, 256)  524544     ['activation_75[0][0]']
#  nspose)
#
#  batch_normalization_76 (BatchN  (None, 32, 32, 256)  1024       ['Conv2DTranspose_UP1[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_76[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 32, 32, 512)  0           ['activation_76[0][0]',
#                                                                   'activation_73[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_10[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_77[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_77[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_78[0][0]']
#
#  Conv2DTranspose_UP2 (Conv2DTra  (None, 64, 64, 128)  131200     ['activation_78[0][0]']
#  nspose)
#
#  batch_normalization_79 (BatchN  (None, 64, 64, 128)  512        ['Conv2DTranspose_UP2[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_79[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 64, 64, 256)  0           ['activation_79[0][0]',
#                                                                   'activation_71[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_11[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 64, 64, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_80[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_80[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 64, 64, 128)  512        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_81 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_81[0][0]']
#
#  Conv2DTranspose_UP3 (Conv2DTra  (None, 128, 128, 64  32832      ['activation_81[0][0]']
#  nspose)                        )
#
#  batch_normalization_82 (BatchN  (None, 128, 128, 64  256        ['Conv2DTranspose_UP3[0][0]']
#  ormalization)                  )
#
#  activation_82 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_82[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 128, 128, 12  0           ['activation_82[0][0]',
#                                 8)                                'activation_69[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_12[0][0]']
#                                 )
#
#  batch_normalization_83 (BatchN  (None, 128, 128, 64  256        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  activation_83 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_83[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 64  36928       ['activation_83[0][0]']
#                                 )
#
#  batch_normalization_84 (BatchN  (None, 128, 128, 64  256        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  activation_84 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_84[0][0]']
#                                 )
#
#  Conv2DTranspose_UP4 (Conv2DTra  (None, 256, 256, 32  8224       ['activation_84[0][0]']
#  nspose)                        )
#
#  batch_normalization_85 (BatchN  (None, 256, 256, 32  128        ['Conv2DTranspose_UP4[0][0]']
#  ormalization)                  )
#
#  activation_85 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_85[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 256, 256, 64  0           ['activation_85[0][0]',
#                                 )                                 'activation_67[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_13[0][0]']
#                                 )
#
#  batch_normalization_86 (BatchN  (None, 256, 256, 32  128        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  activation_86 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_86[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 256, 256, 32  9248        ['activation_86[0][0]']
#                                 )
#
#  batch_normalization_87 (BatchN  (None, 256, 256, 32  128        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  activation_87 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_87[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 256, 256, 1)  289         ['activation_87[0][0]']
#
# ==================================================================================================
# Total params: 7,774,049
# Trainable params: 7,767,201
# Non-trainable params: 6,848
# __________________________________________________________________________________________________

# %% [markdown]
# ## 4. Model training

# %%
history = model.fit(train, 
          epochs=40, 
          validation_data= val,
          steps_per_epoch= len(x_train)// BATCHSIZE,
          validation_steps= len(x_test) // BATCHSIZE,
          verbose=1
          )
# Out:
# Found 3143 validated image filenames.
# Found 3143 validated image filenames.
# Epoch 1/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0369Found 786 validated image filenames.
# Found 786 validated image filenames.
# 196/196 [==============================] - 42s 205ms/step - loss: 0.0369 - val_loss: 0.0496
# Epoch 2/40
# 196/196 [==============================] - 39s 199ms/step - loss: 0.0250 - val_loss: 0.0379
# Epoch 3/40
# 196/196 [==============================] - 40s 206ms/step - loss: 0.0224 - val_loss: 0.1005
# Epoch 4/40
# 196/196 [==============================] - 39s 199ms/step - loss: 0.0189 - val_loss: 0.0191
# Epoch 5/40
# 196/196 [==============================] - 39s 201ms/step - loss: 0.0178 - val_loss: 0.0217
# Epoch 6/40
# 196/196 [==============================] - 39s 201ms/step - loss: 0.0165 - val_loss: 0.0270
# Epoch 7/40
# 196/196 [==============================] - 38s 193ms/step - loss: 0.0155 - val_loss: 0.0292
# Epoch 8/40
# 196/196 [==============================] - 37s 191ms/step - loss: 0.0153 - val_loss: 0.0179
# Epoch 9/40
# 196/196 [==============================] - 37s 190ms/step - loss: 0.0142 - val_loss: 0.0217
# Epoch 10/40
# 196/196 [==============================] - 37s 190ms/step - loss: 0.0132 - val_loss: 0.0178
# Epoch 11/40
# 196/196 [==============================] - 37s 190ms/step - loss: 0.0128 - val_loss: 0.0144
# Epoch 12/40
# 196/196 [==============================] - 38s 194ms/step - loss: 0.0116 - val_loss: 0.0150
# Epoch 13/40
# 196/196 [==============================] - 37s 190ms/step - loss: 0.0110 - val_loss: 0.0134
# Epoch 14/40
# 196/196 [==============================] - 38s 193ms/step - loss: 0.0104 - val_loss: 0.0131
# Epoch 15/40
# 196/196 [==============================] - 38s 193ms/step - loss: 0.0099 - val_loss: 0.0159
# Epoch 16/40
# 196/196 [==============================] - 39s 199ms/step - loss: 0.0093 - val_loss: 0.0111
# Epoch 17/40
# 196/196 [==============================] - 40s 202ms/step - loss: 0.0089 - val_loss: 0.0129
# Epoch 18/40
# 196/196 [==============================] - 39s 198ms/step - loss: 0.0088 - val_loss: 0.0103
# Epoch 19/40
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0082 - val_loss: 0.0222
# Epoch 20/40
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 21/40
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0073 - val_loss: 0.0117
# Epoch 22/40
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0073 - val_loss: 0.0087
# Epoch 23/40
# 196/196 [==============================] - 39s 197ms/step - loss: 0.0066 - val_loss: 0.0081
# Epoch 24/40
# 196/196 [==============================] - 39s 198ms/step - loss: 0.0063 - val_loss: 0.0087
# Epoch 25/40
# 196/196 [==============================] - 39s 199ms/step - loss: 0.0061 - val_loss: 0.0079
# Epoch 26/40
# 196/196 [==============================] - 39s 200ms/step - loss: 0.0058 - val_loss: 0.0094
# Epoch 27/40
# 196/196 [==============================] - 40s 202ms/step - loss: 0.0076 - val_loss: 0.0248
# Epoch 28/40
# 196/196 [==============================] - 40s 203ms/step - loss: 0.0059 - val_loss: 0.0091
# Epoch 29/40
# 196/196 [==============================] - 39s 198ms/step - loss: 0.0052 - val_loss: 0.0075
# Epoch 30/40
# 196/196 [==============================] - 40s 202ms/step - loss: 0.0050 - val_loss: 0.0092
# Epoch 31/40
# 196/196 [==============================] - 39s 200ms/step - loss: 0.0047 - val_loss: 0.0079
# Epoch 32/40
# 196/196 [==============================] - 39s 200ms/step - loss: 0.0048 - val_loss: 0.0084
# Epoch 33/40
# 196/196 [==============================] - 39s 200ms/step - loss: 0.0044 - val_loss: 0.0093
# Epoch 34/40
# 196/196 [==============================] - 40s 206ms/step - loss: 0.0046 - val_loss: 0.0141
# Epoch 35/40
# 196/196 [==============================] - 40s 202ms/step - loss: 0.0069 - val_loss: 0.0084
# Epoch 36/40
# 196/196 [==============================] - 40s 202ms/step - loss: 0.0043 - val_loss: 0.0106
# Epoch 37/40
# 196/196 [==============================] - 40s 202ms/step - loss: 0.0040 - val_loss: 0.0118
# Epoch 38/40
# 196/196 [==============================] - 39s 201ms/step - loss: 0.0039 - val_loss: 0.0085
# Epoch 39/40
# 196/196 [==============================] - 40s 203ms/step - loss: 0.0038 - val_loss: 0.0074
# Epoch 40/40
# 196/196 [==============================] - 40s 203ms/step - loss: 0.0042 - val_loss: 0.0090

# %% [markdown]
# ## 5. Evaluation

# %%
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Save outputs

# %%
if not(os.path.exists('model_output_paper')):
    os.mkdir('model_output_paper')

nSaveImages = 50
for im in range(nSaveImages):
    rows = 3
    cols = 4
    fig, axs = plt.subplots(rows, cols, figsize = (60, 60))    

    for i in range(rows):

        idx = np.random.randint(0,nSamples-1)
        img = PIL.Image.open(data['original'][idx])
        lbl = PIL.Image.open(data['mask'][idx])
        
        
        pred = model.predict(np.expand_dims(np.array(img)/255,0))
        
        axs[i,0].imshow(img), axs[i,0].set_title('original',fontsize=50)
        axs[i,1].imshow(lbl), axs[i,1].set_title('label',fontsize=50)

        axs[i,2].imshow(img), axs[i,2].set_title('automatic segmentation', fontsize=50)
        axs[i,2].imshow(pred[0], alpha=((pred[0] > 0.1) * 0.5)[:,:,0])

        axs[i,3].imshow(pred[0], cmap='gray'), axs[i,3].set_title('predicted',fontsize=50)
        
    fig.suptitle('MODEL EVALUATION', fontsize=50)
    import uuid
    figname = uuid.uuid1()
    fig.savefig('model_output_paper/'+str(figname))
    plt.close()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
